# %% [markdown]
# # This notebook is in Python3.  You can still execute the notebook in Python2, but beware of the [differences](http://sebastianraschka.com/Articles/2014_python_2_3_key_diff.html)

# %%
# variable types in python:
# string

from __future__ import print_function

test_string = 'this is a string'
print(test_string)
# Out:
# this is a string

# %%
# integer
test_int = 1
print(test_int)
# Out:
# 1

# %%
# float (has a decimal place)
test_float = 1.0
print(test_float)
# Out:
# 1.0

# %%
# checking type of variable
type(test_float)
# Out:
# float

# %%
# converting (called 'type-casting')
int(test_float)
# Out:
# 1

# %%
# lists: the default 'arrays' in python
# this is like doing c(1, 2, 3, 4) in R
test_list = [1, 2, 3, 4]
test_list
# Out:
# [1, 2, 3, 4]

# %%
# listed can be appended to:
test_list.append(3)
test_list
# Out:
# [1, 2, 3, 4, 3]

# %%
test_list.extend([1, 2, 3])
test_list
# Out:
# [1, 2, 3, 4, 3, 1, 2, 3]

# %%
# one of the built-in functions in python: https://docs.python.org/3/library/functions.html
sum(test_list)
# Out:
# 19

# %%
# for loops
for i in test_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 3
# 1
# 2
# 3

# %%
# list comprehensions: can embed loops
new_list = [i + 10 for i in test_list]
new_list
# Out:
# [11, 12, 13, 14, 13, 11, 12, 13]

# %%
# a similar data type: tuples
# these are 'immutable'.  lists are 'mutable'.  Anyone know what the difference is?
test_tuple = (1, 2, 3, 4)

# %%
test_tuple.append(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-6aaef1d6401d> in <module>()
# ----> 1 test_tuple.append(1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# how do we append to a tuple? let's add 1 to the end of it
new_t=tuple(list(test_tuple) + [0])

# %%
new_t
# Out:
# (1, 2, 3, 4, 0)

# %%
# a few other very important data types: dictionaries and sets:
test_dict = {'key':'value', 1:2}

# %%
# the lookup times are instant, thanks to something called 'hashing' https://en.wikipedia.org/wiki/Hash_function
test_dict['key']
# Out:
# 'value'

# %%
# sets are collections of unique values.  a concept from discrete math (I think)
print(test_list)
test_set = set(test_list)
# Out:
# [1, 2, 3, 4, 3, 1, 2, 3]

# %%
# what will test_set look like?

test_set
# Out:
# {1, 2, 3, 4}

# %%
# functions encapsulate a task: http://www.cs.utah.edu/~germain/PPS/Topics/functions.html
# for example:
def print_hello(name='Bob'):
    print('Hello, ' + name + '!')

# %%
print_hello()
# Out:
# Hello, Bob!

# %%
print_hello(name='Bip')
# Out:
# Hello, Bip!

# %%
def add_10(x):
    return x + 10

# %%
[add_10(i) for i in test_list]
# Out:
# [11, 12, 13, 14, 13, 11, 12, 13]

# %%
# lambda functions: don't require a definition of the function beforehand
# http://www.secnetix.de/olli/Python/lambda_functions.hawk
# http://stackoverflow.com/questions/6076270/python-lambda-function-in-list-comprehensions
# 
# map is a built-in function: https://docs.python.org/3/library/functions.html
map(lambda x: x + 10, test_list)
# it returns a 'generator' https://wiki.python.org/moin/Generators
# Out:
# [11, 12, 13, 14, 13, 11, 12, 13]

# %%
# how do we type-cast it to a list?
list(map(lambda x: x + 10, test_list))
# Out:
# [11, 12, 13, 14, 13, 11, 12, 13]

# %%
# load modules with import:
# two very common ones for analytics/data science: pandas and numpy
import numpy as np
import pandas as pd
# we can give a module any alias we want, e.g. import pandas as cool_thing

# %%
# a module is a collection of code in some files.  To see the location, we can do
pd.__file__
# Out:
# 'C:\\Users\\Jeane\\Anaconda3\\envs\\py2\\lib\\site-packages\\pandas\\__init__.pyc'

# %%
# if you type `pd.__`, then hit tab a few times, you can scroll through the list of possibilities to complete the line.
# the two I use most are pd.__file__ and pd.__version__
pd.__version__
# Out:
# u'0.19.2'

# %%
# sometimes you'll see imports like this:
from pandas import read_csv
# this allows us to only import that one function (read_csv) from the module (pandas)

# %%
# numpy has their own type of list, called an array:
test_array = np.array(test_list)
print(test_array)
print(test_array.dtype)
# Out:
# [1 2 3 4 3 1 2 3]
# int32

# %%
test_array
# Out:
# array([1, 2, 3, 4, 3, 1, 2, 3])

# %%
np.random.randint(10)
# Out:
# 3

# %%
# there are a lot of things you can do with arrays that you can't do with lists:
np.argmax(test_array)
# Out:
# 3

# %%
test_array[3]
# Out:
# 4

# %%
#shows only the unique values similar to R
np.unique(test_array)
# Out:
# array([1, 2, 3, 4])

# %%
# pandas can read csv's easily; there are a ton of options for it: 
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html

# optional todo: try looking at data from https://www.kaggle.com/openfoodfacts/world-food-facts
pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-a6ebde73f6f2> in <module>()
#       3
#       4 # optional todo: try looking at data from https://www.kaggle.com/openfoodfacts/world-food-facts
# ----> 5 pd.read_csv()
#
# TypeError: parser_f() takes at least 1 argument (0 given)

# %% [markdown]
# # Calling R functions from Python: it's possible
# ## Optional : I wouldn't try to install during class.  Try it outside the classroom, somewhere where the internet is fast.
#
# ### First we need to install rpy2:
#
# ### In a terminal:
# `conda install -c r rpy2=2.8.5`
#
# ### Documentation here: http://rpy.sourceforge.net/rpy2/doc-dev/html/introduction.html
#
# ### one tutorial here: http://blog.yhat.com/posts/rpy2-combing-the-power-of-r-and-python.html

# %%
# if you can get rpy2 installed, try running this.  Otherwise skip this cell
import rpy2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-47-cffe9f862b94> in <module>()
#       1 # if you can get rpy2 installed, try running this.  Otherwise skip this cell
# ----> 2 import rpy2
#
# ImportError: No module named rpy2

# %%
# seaborn has some built-in data
import seaborn as sns

# %%
# the famous Anscombe's quartet: https://en.wikipedia.org/wiki/Anscombe%27s_quartet
ans = sns.load_dataset('anscombe')

# %%
type(ans)
# Out:
# pandas.core.frame.DataFrame

# %%
ans.head() # shows the first few rows of our data
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
ans.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
ans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
# dataset    44 non-null object
# x          44 non-null float64
# y          44 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.1+ KB

# %%
ans.max()
# Out:
# dataset       IV
# x             19
# y          12.74
# dtype: object

# %%
# pandas uses numpy functions for a lot of things:
ans['dataset'].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
np.unique(ans['dataset'].values)
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
# how do we get the max of the 'x' column?
ans['x'].max()
# Out:
# 19.0

# %%
# how do we rename the column 'dataset' to 'group'?
# hint: google 'python pandas rename' or 'pandas rename'

# %%
ans['dataset'] == 'I'
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# Name: dataset, dtype: bool

# %%
# pandas has some built-in plotting, but we need to load matplotlib first:
import matplotlib.pyplot as plt

f = ans[ans['dataset'] == 'III'].plot(x='x', y='y', kind='scatter')
plt.show()

# %%
# what does this look like?
# ans['dataset'] == 'I'

# %%
# ok, so what is it doing when we index the dataframe with it?
# ans[ans['dataset'] == 'I']

# %%
# to group by the dataset, we would do this:
groups = ans.groupby('dataset')

# %%
# it's a generator object, so we can't see the data until we're looping through it
type(groups)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
gr = list(groups)

# %%
groups.mean()
# Out:
#            x         y
# dataset
# I        9.0  7.500909
# II       9.0  7.500909
# III      9.0  7.500000
# IV       9.0  7.500909

# %%
gr[0] # it's a tuple, of (group, dataframe)
# Out:
# ('I',    dataset     x      y
#  0        I  10.0   8.04
#  1        I   8.0   6.95
#  2        I  13.0   7.58
#  3        I   9.0   8.81
#  4        I  11.0   8.33
#  5        I  14.0   9.96
#  6        I   6.0   7.24
#  7        I   4.0   4.26
#  8        I  12.0  10.84
#  9        I   7.0   4.82
#  10       I   5.0   5.68)

# %% [markdown]
# # Alright, let's do the warmup!  -- see worldclass for the files (Content -> Course Resources -> Warmups) W3_warmup.html and salary_data.csv

# %%
sd=read_csv("salary_data.csv")

# %%
sd
# Out:
#                            name  \
# 0               AARON,  ELVIA J
# 1             AARON,  JEFFERY M
# 2                AARON,  KARINA
# 3           AARON,  KIMBERLEI R
# 4           ABAD JR,  VICENTE M
# 5               ABARCA,  ANABEL
# 6             ABARCA,  EMMANUEL
# 7         ABBATACOLA,  ROBERT J
# 8         ABBATEMARCO,  JAMES J
# 9              ABBATE,  TERRY M
# 10             ABBOTT,  BETTY L
# 11            ABBOTT,  LYNISE M
# 12       ABBRUZZESE,  WILLIAM J
# 13              ABDALLAH,  ZAID
# 14        ABDELHADI,  ABDALMAHD
# 15          ABDELLATIF,  AREF R
# 16           ABDELMAJEID,  AZIZ
# 17          ABDOLLAHZADEH,  ALI
# 18     ABDUL-KARIM,  MUHAMMAD A
# 19             ABDULLAH,  ASKIA
# 20          ABDULLAH,  DANIEL N
# 21             ABDULLAH,  KEVIN
# 22         ABDULLAH,  LAKENYA N
# 23          ABDULLAH,  RASHAD J
# 24         ABDUL-SHAKUR,  TAHIR
# 25            ABEJERO,  JASON V
# 26        ABERCROMBIE,  TIMOTHY
# 27       ABOUELKHEIR,  HASSAN A
# 28           ABRAHAM,  GIRLEY T
# 29           ABRAHAM,  GODWIN K
# ...                         ...
# 32130           ZUNIGA,  JUAN M
# 32131           ZUNIGA,  JURDON
# 32132            ZUNIGA,  OSCAR
# 32133           ZUNIGA,  RONALD
# 32134           ZUNIGA,  THOMAS
# 32135          ZUNIGA,  VICENTE
# 32136               ZUNO,  ERIK
# 32137            ZUPAN,  BILL M
# 32138        ZUPAN,  VICTORIA J
# 32139        ZURAWSKI,  CAROL A
# 32140        ZURAWSKI,  JEFFREY
# 32141          ZURAWSKI,  MAC Z
# 32142         ZURAWSKI,  MARY E
# 32143           ZUREK,  FRANCIS
# 32144             ZUREK,  HENRY
# 32145            ZUREK,  MARY H
# 32146           ZVANJA,  TINA M
# 32147    ZWARYCZ MANN,  IRENE A
# 32148        ZWARYCZ,  THOMAS J
# 32149        ZWIESLER,  MATTHEW
# 32150          ZWIT,  JEFFREY J
# 32151       ZWOLFER,  MATTHEW W
# 32152          ZWOLSKI,  MARY L
# 32153             ZYDEK,  BRYAN
# 32154          ZYGADLO,  JOHN P
# 32155       ZYGADLO,  MICHAEL J
# 32156        ZYGOWICZ,  PETER J
# 32157         ZYMANTAS,  MARK E
# 32158       ZYRKOWSKI,  CARLO E
# 32159       ZYSKOWSKI,  DARIUSZ
#
#                                            job_title        department  \
# 0                                   WATER RATE TAKER       WATER MGMNT
# 1                                     POLICE OFFICER            POLICE
# 2                                     POLICE OFFICER            POLICE
# 3                           CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4                                  CIVIL ENGINEER IV       WATER MGMNT
# 5                               ASST TO THE ALDERMAN      CITY COUNCIL
# 6                              GENERAL LABORER - DSS     STREETS & SAN
# 7                                ELECTRICAL MECHANIC          AVIATION
# 8                                      FIRE ENGINEER              FIRE
# 9                                     POLICE OFFICER            POLICE
# 10                                FOSTER GRANDPARENT  FAMILY & SUPPORT
# 11                                         CLERK III            POLICE
# 12                            INVESTIGATOR - IPRA II              IPRA
# 13                                    POLICE OFFICER            POLICE
# 14                                    POLICE OFFICER            POLICE
# 15     FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC              FIRE
# 16                                    POLICE OFFICER            POLICE
# 17                                     PARAMEDIC I/C              FIRE
# 18                         ENGINEERING TECHNICIAN VI       WATER MGMNT
# 19                                  LEGISLATIVE AIDE      CITY COUNCIL
# 20                                   FIREFIGHTER-EMT              FIRE
# 21                                        LIEUTENANT              FIRE
# 22                                    CROSSING GUARD            POLICE
# 23           ELECTRICAL MECHANIC-AUTO-POLICE MTR MNT  GENERAL SERVICES
# 24                             GENERAL LABORER - DSS     STREETS & SAN
# 25                                    POLICE OFFICER            POLICE
# 26                                MOTOR TRUCK DRIVER     STREETS & SAN
# 27                         SENIOR PROGRAMMER/ANALYST  FAMILY & SUPPORT
# 28                                 CIVIL ENGINEER IV       WATER MGMNT
# 29                          ENGINEERING TECHNICIAN V  BUSINESS AFFAIRS
# ...                                              ...               ...
# 32130                                 POLICE OFFICER            POLICE
# 32131                                 POLICE OFFICER            POLICE
# 32132                                 POLICE OFFICER            POLICE
# 32133                                 POLICE OFFICER            POLICE
# 32134                          GENERAL LABORER - DSS     STREETS & SAN
# 32135                                FIREFIGHTER-EMT              FIRE
# 32136                           LABORER - APPRENTICE       WATER MGMNT
# 32137                                 LIEUTENANT-EMT              FIRE
# 32138                                 POLICE OFFICER            POLICE
# 32139                                 CROSSING GUARD            POLICE
# 32140                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32141                             SANITATION LABORER     STREETS & SAN
# 32142                                 POLICE OFFICER            POLICE
# 32143                            ELECTRICAL MECHANIC              OEMC
# 32144                           CONSTRUCTION LABORER       WATER MGMNT
# 32145              SENIOR PUBLIC INFORMATION OFFICER           FINANCE
# 32146                                LEGAL SECRETARY               LAW
# 32147                                 CROSSING GUARD            POLICE
# 32148                        POOL MOTOR TRUCK DRIVER       WATER MGMNT
# 32149                    AIRPORT OPERATIONS SUPVSR I          AVIATION
# 32150                                 POLICE OFFICER            POLICE
# 32151                                FIREFIGHTER-EMT              FIRE
# 32152                                 POLICE OFFICER            POLICE
# 32153                                 POLICE OFFICER            POLICE
# 32154                         MACHINIST (AUTOMOTIVE)  GENERAL SERVICES
# 32155                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32156                                 POLICE OFFICER            POLICE
# 32157                                 POLICE OFFICER            POLICE
# 32158                                 POLICE OFFICER            POLICE
# 32159                        CHIEF DATA BASE ANALYST              DoIT
#
#           salary            Join Date
# 0       $87228.0  2000-09-27 00:00:00
# 1       $75372.0  2000-08-04 00:00:00
# 2       $75372.0  2000-01-20 00:00:00
# 3       $80916.0  2000-04-27 00:00:00
# 4       $99648.0  2000-02-11 00:00:00
# 5       $70764.0  2000-11-12 00:00:00
# 6       $40560.0  2000-01-13 00:00:00
# 7       $89440.0  2000-03-25 00:00:00
# 8       $84396.0  2000-06-17 00:00:00
# 9       $80724.0  2000-12-01 00:00:00
# 10       $2756.0  2000-06-27 00:00:00
# 11      $41784.0  2000-01-16 00:00:00
# 12      $65808.0  2000-05-24 00:00:00
# 13      $65016.0  2000-05-13 00:00:00
# 14      $75372.0  2000-04-24 00:00:00
# 15      $90738.0  2000-02-22 00:00:00
# 16      $75372.0  2000-03-15 00:00:00
# 17      $81672.0  2000-03-09 00:00:00
# 18      $96384.0  2000-02-27 00:00:00
# 19      $25008.0  2000-07-24 00:00:00
# 20      $84762.0  2000-01-07 00:00:00
# 21     $102978.0  2000-06-16 00:00:00
# 22      $16525.6  2000-03-03 00:00:00
# 23      $89440.0  2000-01-15 00:00:00
# 24      $40560.0  2000-07-27 00:00:00
# 25      $78012.0  2000-03-15 00:00:00
# 26      $70408.0  2000-05-26 00:00:00
# 27      $99648.0  2000-06-02 00:00:00
# 28      $99648.0  2000-02-12 00:00:00
# 29      $91980.0  2000-12-08 00:00:00
# ...          ...                  ...
# 32130   $78012.0  2000-07-01 00:00:00
# 32131   $61530.0  2000-09-11 00:00:00
# 32132   $65016.0  2000-07-21 00:00:00
# 32133   $78012.0  2000-05-02 00:00:00
# 32134   $41849.6  2000-11-28 00:00:00
# 32135   $79140.0  2000-03-27 00:00:00
# 32136   $46176.0  2000-12-11 00:00:00
# 32137   $98394.0  2000-05-13 00:00:00
# 32138   $75372.0  2000-11-24 00:00:00
# 32139   $20872.8  2000-01-07 00:00:00
# 32140   $96553.6  2000-11-28 00:00:00
# 32141   $70969.6  2000-02-02 00:00:00
# 32142   $83706.0  2000-04-04 00:00:00
# 32143   $89440.0  2000-03-07 00:00:00
# 32144   $76960.0  2000-03-04 00:00:00
# 32145   $80916.0  2000-05-22 00:00:00
# 32146   $66492.0  2000-05-03 00:00:00
# 32147   $16525.6  2000-03-15 00:00:00
# 32148   $70408.0  2000-11-02 00:00:00
# 32149   $68472.0  2000-10-15 00:00:00
# 32150   $78012.0  2000-02-15 00:00:00
# 32151   $81906.0  2000-06-01 00:00:00
# 32152   $80724.0  2000-03-04 00:00:00
# 32153   $75372.0  2000-10-04 00:00:00
# 32154   $91353.6  2000-08-21 00:00:00
# 32155   $96553.6  2000-05-24 00:00:00
# 32156   $80724.0  2000-03-09 00:00:00
# 32157   $78012.0  2000-01-07 00:00:00
# 32158   $80724.0  2000-05-02 00:00:00
# 32159  $110352.0  2000-08-10 00:00:00
#
# [32160 rows x 5 columns]

# %%
sd.columns = ['Name','Job','Department','Salary','Date']

# %%
sd
# Out:
#                            Name  \
# 0               AARON,  ELVIA J
# 1             AARON,  JEFFERY M
# 2                AARON,  KARINA
# 3           AARON,  KIMBERLEI R
# 4           ABAD JR,  VICENTE M
# 5               ABARCA,  ANABEL
# 6             ABARCA,  EMMANUEL
# 7         ABBATACOLA,  ROBERT J
# 8         ABBATEMARCO,  JAMES J
# 9              ABBATE,  TERRY M
# 10             ABBOTT,  BETTY L
# 11            ABBOTT,  LYNISE M
# 12       ABBRUZZESE,  WILLIAM J
# 13              ABDALLAH,  ZAID
# 14        ABDELHADI,  ABDALMAHD
# 15          ABDELLATIF,  AREF R
# 16           ABDELMAJEID,  AZIZ
# 17          ABDOLLAHZADEH,  ALI
# 18     ABDUL-KARIM,  MUHAMMAD A
# 19             ABDULLAH,  ASKIA
# 20          ABDULLAH,  DANIEL N
# 21             ABDULLAH,  KEVIN
# 22         ABDULLAH,  LAKENYA N
# 23          ABDULLAH,  RASHAD J
# 24         ABDUL-SHAKUR,  TAHIR
# 25            ABEJERO,  JASON V
# 26        ABERCROMBIE,  TIMOTHY
# 27       ABOUELKHEIR,  HASSAN A
# 28           ABRAHAM,  GIRLEY T
# 29           ABRAHAM,  GODWIN K
# ...                         ...
# 32130           ZUNIGA,  JUAN M
# 32131           ZUNIGA,  JURDON
# 32132            ZUNIGA,  OSCAR
# 32133           ZUNIGA,  RONALD
# 32134           ZUNIGA,  THOMAS
# 32135          ZUNIGA,  VICENTE
# 32136               ZUNO,  ERIK
# 32137            ZUPAN,  BILL M
# 32138        ZUPAN,  VICTORIA J
# 32139        ZURAWSKI,  CAROL A
# 32140        ZURAWSKI,  JEFFREY
# 32141          ZURAWSKI,  MAC Z
# 32142         ZURAWSKI,  MARY E
# 32143           ZUREK,  FRANCIS
# 32144             ZUREK,  HENRY
# 32145            ZUREK,  MARY H
# 32146           ZVANJA,  TINA M
# 32147    ZWARYCZ MANN,  IRENE A
# 32148        ZWARYCZ,  THOMAS J
# 32149        ZWIESLER,  MATTHEW
# 32150          ZWIT,  JEFFREY J
# 32151       ZWOLFER,  MATTHEW W
# 32152          ZWOLSKI,  MARY L
# 32153             ZYDEK,  BRYAN
# 32154          ZYGADLO,  JOHN P
# 32155       ZYGADLO,  MICHAEL J
# 32156        ZYGOWICZ,  PETER J
# 32157         ZYMANTAS,  MARK E
# 32158       ZYRKOWSKI,  CARLO E
# 32159       ZYSKOWSKI,  DARIUSZ
#
#                                                  Job        Department  \
# 0                                   WATER RATE TAKER       WATER MGMNT
# 1                                     POLICE OFFICER            POLICE
# 2                                     POLICE OFFICER            POLICE
# 3                           CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4                                  CIVIL ENGINEER IV       WATER MGMNT
# 5                               ASST TO THE ALDERMAN      CITY COUNCIL
# 6                              GENERAL LABORER - DSS     STREETS & SAN
# 7                                ELECTRICAL MECHANIC          AVIATION
# 8                                      FIRE ENGINEER              FIRE
# 9                                     POLICE OFFICER            POLICE
# 10                                FOSTER GRANDPARENT  FAMILY & SUPPORT
# 11                                         CLERK III            POLICE
# 12                            INVESTIGATOR - IPRA II              IPRA
# 13                                    POLICE OFFICER            POLICE
# 14                                    POLICE OFFICER            POLICE
# 15     FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC              FIRE
# 16                                    POLICE OFFICER            POLICE
# 17                                     PARAMEDIC I/C              FIRE
# 18                         ENGINEERING TECHNICIAN VI       WATER MGMNT
# 19                                  LEGISLATIVE AIDE      CITY COUNCIL
# 20                                   FIREFIGHTER-EMT              FIRE
# 21                                        LIEUTENANT              FIRE
# 22                                    CROSSING GUARD            POLICE
# 23           ELECTRICAL MECHANIC-AUTO-POLICE MTR MNT  GENERAL SERVICES
# 24                             GENERAL LABORER - DSS     STREETS & SAN
# 25                                    POLICE OFFICER            POLICE
# 26                                MOTOR TRUCK DRIVER     STREETS & SAN
# 27                         SENIOR PROGRAMMER/ANALYST  FAMILY & SUPPORT
# 28                                 CIVIL ENGINEER IV       WATER MGMNT
# 29                          ENGINEERING TECHNICIAN V  BUSINESS AFFAIRS
# ...                                              ...               ...
# 32130                                 POLICE OFFICER            POLICE
# 32131                                 POLICE OFFICER            POLICE
# 32132                                 POLICE OFFICER            POLICE
# 32133                                 POLICE OFFICER            POLICE
# 32134                          GENERAL LABORER - DSS     STREETS & SAN
# 32135                                FIREFIGHTER-EMT              FIRE
# 32136                           LABORER - APPRENTICE       WATER MGMNT
# 32137                                 LIEUTENANT-EMT              FIRE
# 32138                                 POLICE OFFICER            POLICE
# 32139                                 CROSSING GUARD            POLICE
# 32140                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32141                             SANITATION LABORER     STREETS & SAN
# 32142                                 POLICE OFFICER            POLICE
# 32143                            ELECTRICAL MECHANIC              OEMC
# 32144                           CONSTRUCTION LABORER       WATER MGMNT
# 32145              SENIOR PUBLIC INFORMATION OFFICER           FINANCE
# 32146                                LEGAL SECRETARY               LAW
# 32147                                 CROSSING GUARD            POLICE
# 32148                        POOL MOTOR TRUCK DRIVER       WATER MGMNT
# 32149                    AIRPORT OPERATIONS SUPVSR I          AVIATION
# 32150                                 POLICE OFFICER            POLICE
# 32151                                FIREFIGHTER-EMT              FIRE
# 32152                                 POLICE OFFICER            POLICE
# 32153                                 POLICE OFFICER            POLICE
# 32154                         MACHINIST (AUTOMOTIVE)  GENERAL SERVICES
# 32155                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32156                                 POLICE OFFICER            POLICE
# 32157                                 POLICE OFFICER            POLICE
# 32158                                 POLICE OFFICER            POLICE
# 32159                        CHIEF DATA BASE ANALYST              DoIT
#
#           Salary                 Date
# 0       $87228.0  2000-09-27 00:00:00
# 1       $75372.0  2000-08-04 00:00:00
# 2       $75372.0  2000-01-20 00:00:00
# 3       $80916.0  2000-04-27 00:00:00
# 4       $99648.0  2000-02-11 00:00:00
# 5       $70764.0  2000-11-12 00:00:00
# 6       $40560.0  2000-01-13 00:00:00
# 7       $89440.0  2000-03-25 00:00:00
# 8       $84396.0  2000-06-17 00:00:00
# 9       $80724.0  2000-12-01 00:00:00
# 10       $2756.0  2000-06-27 00:00:00
# 11      $41784.0  2000-01-16 00:00:00
# 12      $65808.0  2000-05-24 00:00:00
# 13      $65016.0  2000-05-13 00:00:00
# 14      $75372.0  2000-04-24 00:00:00
# 15      $90738.0  2000-02-22 00:00:00
# 16      $75372.0  2000-03-15 00:00:00
# 17      $81672.0  2000-03-09 00:00:00
# 18      $96384.0  2000-02-27 00:00:00
# 19      $25008.0  2000-07-24 00:00:00
# 20      $84762.0  2000-01-07 00:00:00
# 21     $102978.0  2000-06-16 00:00:00
# 22      $16525.6  2000-03-03 00:00:00
# 23      $89440.0  2000-01-15 00:00:00
# 24      $40560.0  2000-07-27 00:00:00
# 25      $78012.0  2000-03-15 00:00:00
# 26      $70408.0  2000-05-26 00:00:00
# 27      $99648.0  2000-06-02 00:00:00
# 28      $99648.0  2000-02-12 00:00:00
# 29      $91980.0  2000-12-08 00:00:00
# ...          ...                  ...
# 32130   $78012.0  2000-07-01 00:00:00
# 32131   $61530.0  2000-09-11 00:00:00
# 32132   $65016.0  2000-07-21 00:00:00
# 32133   $78012.0  2000-05-02 00:00:00
# 32134   $41849.6  2000-11-28 00:00:00
# 32135   $79140.0  2000-03-27 00:00:00
# 32136   $46176.0  2000-12-11 00:00:00
# 32137   $98394.0  2000-05-13 00:00:00
# 32138   $75372.0  2000-11-24 00:00:00
# 32139   $20872.8  2000-01-07 00:00:00
# 32140   $96553.6  2000-11-28 00:00:00
# 32141   $70969.6  2000-02-02 00:00:00
# 32142   $83706.0  2000-04-04 00:00:00
# 32143   $89440.0  2000-03-07 00:00:00
# 32144   $76960.0  2000-03-04 00:00:00
# 32145   $80916.0  2000-05-22 00:00:00
# 32146   $66492.0  2000-05-03 00:00:00
# 32147   $16525.6  2000-03-15 00:00:00
# 32148   $70408.0  2000-11-02 00:00:00
# 32149   $68472.0  2000-10-15 00:00:00
# 32150   $78012.0  2000-02-15 00:00:00
# 32151   $81906.0  2000-06-01 00:00:00
# 32152   $80724.0  2000-03-04 00:00:00
# 32153   $75372.0  2000-10-04 00:00:00
# 32154   $91353.6  2000-08-21 00:00:00
# 32155   $96553.6  2000-05-24 00:00:00
# 32156   $80724.0  2000-03-09 00:00:00
# 32157   $78012.0  2000-01-07 00:00:00
# 32158   $80724.0  2000-05-02 00:00:00
# 32159  $110352.0  2000-08-10 00:00:00
#
# [32160 rows x 5 columns]

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32160 entries, 0 to 32159
# Data columns (total 5 columns):
# Name          32160 non-null object
# Job           32160 non-null object
# Department    32160 non-null object
# Salary        32160 non-null object
# Date          32160 non-null object
# dtypes: object(5)
# memory usage: 1.2+ MB

# %%
sd.head()
# Out:
#                   Name                       Job        Department    Salary  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT  $87228.0
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE  $75372.0
# 2       AARON,  KARINA            POLICE OFFICER            POLICE  $75372.0
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES  $80916.0
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT  $99648.0
#
#                   Date
# 0  2000-09-27 00:00:00
# 1  2000-08-04 00:00:00
# 2  2000-01-20 00:00:00
# 3  2000-04-27 00:00:00
# 4  2000-02-11 00:00:00

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32160 entries, 0 to 32159
# Data columns (total 5 columns):
# Name          32160 non-null object
# Job           32160 non-null object
# Department    32160 non-null object
# Salary        32160 non-null object
# Date          32160 non-null object
# dtypes: object(5)
# memory usage: 1.2+ MB

# %%
sd[['Date']]=sd[["Date"]].apply(pd.to_datetime)

# %%
sd
# Out:
#                            Name  \
# 0               AARON,  ELVIA J
# 1             AARON,  JEFFERY M
# 2                AARON,  KARINA
# 3           AARON,  KIMBERLEI R
# 4           ABAD JR,  VICENTE M
# 5               ABARCA,  ANABEL
# 6             ABARCA,  EMMANUEL
# 7         ABBATACOLA,  ROBERT J
# 8         ABBATEMARCO,  JAMES J
# 9              ABBATE,  TERRY M
# 10             ABBOTT,  BETTY L
# 11            ABBOTT,  LYNISE M
# 12       ABBRUZZESE,  WILLIAM J
# 13              ABDALLAH,  ZAID
# 14        ABDELHADI,  ABDALMAHD
# 15          ABDELLATIF,  AREF R
# 16           ABDELMAJEID,  AZIZ
# 17          ABDOLLAHZADEH,  ALI
# 18     ABDUL-KARIM,  MUHAMMAD A
# 19             ABDULLAH,  ASKIA
# 20          ABDULLAH,  DANIEL N
# 21             ABDULLAH,  KEVIN
# 22         ABDULLAH,  LAKENYA N
# 23          ABDULLAH,  RASHAD J
# 24         ABDUL-SHAKUR,  TAHIR
# 25            ABEJERO,  JASON V
# 26        ABERCROMBIE,  TIMOTHY
# 27       ABOUELKHEIR,  HASSAN A
# 28           ABRAHAM,  GIRLEY T
# 29           ABRAHAM,  GODWIN K
# ...                         ...
# 32130           ZUNIGA,  JUAN M
# 32131           ZUNIGA,  JURDON
# 32132            ZUNIGA,  OSCAR
# 32133           ZUNIGA,  RONALD
# 32134           ZUNIGA,  THOMAS
# 32135          ZUNIGA,  VICENTE
# 32136               ZUNO,  ERIK
# 32137            ZUPAN,  BILL M
# 32138        ZUPAN,  VICTORIA J
# 32139        ZURAWSKI,  CAROL A
# 32140        ZURAWSKI,  JEFFREY
# 32141          ZURAWSKI,  MAC Z
# 32142         ZURAWSKI,  MARY E
# 32143           ZUREK,  FRANCIS
# 32144             ZUREK,  HENRY
# 32145            ZUREK,  MARY H
# 32146           ZVANJA,  TINA M
# 32147    ZWARYCZ MANN,  IRENE A
# 32148        ZWARYCZ,  THOMAS J
# 32149        ZWIESLER,  MATTHEW
# 32150          ZWIT,  JEFFREY J
# 32151       ZWOLFER,  MATTHEW W
# 32152          ZWOLSKI,  MARY L
# 32153             ZYDEK,  BRYAN
# 32154          ZYGADLO,  JOHN P
# 32155       ZYGADLO,  MICHAEL J
# 32156        ZYGOWICZ,  PETER J
# 32157         ZYMANTAS,  MARK E
# 32158       ZYRKOWSKI,  CARLO E
# 32159       ZYSKOWSKI,  DARIUSZ
#
#                                                  Job        Department  \
# 0                                   WATER RATE TAKER       WATER MGMNT
# 1                                     POLICE OFFICER            POLICE
# 2                                     POLICE OFFICER            POLICE
# 3                           CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4                                  CIVIL ENGINEER IV       WATER MGMNT
# 5                               ASST TO THE ALDERMAN      CITY COUNCIL
# 6                              GENERAL LABORER - DSS     STREETS & SAN
# 7                                ELECTRICAL MECHANIC          AVIATION
# 8                                      FIRE ENGINEER              FIRE
# 9                                     POLICE OFFICER            POLICE
# 10                                FOSTER GRANDPARENT  FAMILY & SUPPORT
# 11                                         CLERK III            POLICE
# 12                            INVESTIGATOR - IPRA II              IPRA
# 13                                    POLICE OFFICER            POLICE
# 14                                    POLICE OFFICER            POLICE
# 15     FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC              FIRE
# 16                                    POLICE OFFICER            POLICE
# 17                                     PARAMEDIC I/C              FIRE
# 18                         ENGINEERING TECHNICIAN VI       WATER MGMNT
# 19                                  LEGISLATIVE AIDE      CITY COUNCIL
# 20                                   FIREFIGHTER-EMT              FIRE
# 21                                        LIEUTENANT              FIRE
# 22                                    CROSSING GUARD            POLICE
# 23           ELECTRICAL MECHANIC-AUTO-POLICE MTR MNT  GENERAL SERVICES
# 24                             GENERAL LABORER - DSS     STREETS & SAN
# 25                                    POLICE OFFICER            POLICE
# 26                                MOTOR TRUCK DRIVER     STREETS & SAN
# 27                         SENIOR PROGRAMMER/ANALYST  FAMILY & SUPPORT
# 28                                 CIVIL ENGINEER IV       WATER MGMNT
# 29                          ENGINEERING TECHNICIAN V  BUSINESS AFFAIRS
# ...                                              ...               ...
# 32130                                 POLICE OFFICER            POLICE
# 32131                                 POLICE OFFICER            POLICE
# 32132                                 POLICE OFFICER            POLICE
# 32133                                 POLICE OFFICER            POLICE
# 32134                          GENERAL LABORER - DSS     STREETS & SAN
# 32135                                FIREFIGHTER-EMT              FIRE
# 32136                           LABORER - APPRENTICE       WATER MGMNT
# 32137                                 LIEUTENANT-EMT              FIRE
# 32138                                 POLICE OFFICER            POLICE
# 32139                                 CROSSING GUARD            POLICE
# 32140                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32141                             SANITATION LABORER     STREETS & SAN
# 32142                                 POLICE OFFICER            POLICE
# 32143                            ELECTRICAL MECHANIC              OEMC
# 32144                           CONSTRUCTION LABORER       WATER MGMNT
# 32145              SENIOR PUBLIC INFORMATION OFFICER           FINANCE
# 32146                                LEGAL SECRETARY               LAW
# 32147                                 CROSSING GUARD            POLICE
# 32148                        POOL MOTOR TRUCK DRIVER       WATER MGMNT
# 32149                    AIRPORT OPERATIONS SUPVSR I          AVIATION
# 32150                                 POLICE OFFICER            POLICE
# 32151                                FIREFIGHTER-EMT              FIRE
# 32152                                 POLICE OFFICER            POLICE
# 32153                                 POLICE OFFICER            POLICE
# 32154                         MACHINIST (AUTOMOTIVE)  GENERAL SERVICES
# 32155                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32156                                 POLICE OFFICER            POLICE
# 32157                                 POLICE OFFICER            POLICE
# 32158                                 POLICE OFFICER            POLICE
# 32159                        CHIEF DATA BASE ANALYST              DoIT
#
#           Salary       Date
# 0       $87228.0 2000-09-27
# 1       $75372.0 2000-08-04
# 2       $75372.0 2000-01-20
# 3       $80916.0 2000-04-27
# 4       $99648.0 2000-02-11
# 5       $70764.0 2000-11-12
# 6       $40560.0 2000-01-13
# 7       $89440.0 2000-03-25
# 8       $84396.0 2000-06-17
# 9       $80724.0 2000-12-01
# 10       $2756.0 2000-06-27
# 11      $41784.0 2000-01-16
# 12      $65808.0 2000-05-24
# 13      $65016.0 2000-05-13
# 14      $75372.0 2000-04-24
# 15      $90738.0 2000-02-22
# 16      $75372.0 2000-03-15
# 17      $81672.0 2000-03-09
# 18      $96384.0 2000-02-27
# 19      $25008.0 2000-07-24
# 20      $84762.0 2000-01-07
# 21     $102978.0 2000-06-16
# 22      $16525.6 2000-03-03
# 23      $89440.0 2000-01-15
# 24      $40560.0 2000-07-27
# 25      $78012.0 2000-03-15
# 26      $70408.0 2000-05-26
# 27      $99648.0 2000-06-02
# 28      $99648.0 2000-02-12
# 29      $91980.0 2000-12-08
# ...          ...        ...
# 32130   $78012.0 2000-07-01
# 32131   $61530.0 2000-09-11
# 32132   $65016.0 2000-07-21
# 32133   $78012.0 2000-05-02
# 32134   $41849.6 2000-11-28
# 32135   $79140.0 2000-03-27
# 32136   $46176.0 2000-12-11
# 32137   $98394.0 2000-05-13
# 32138   $75372.0 2000-11-24
# 32139   $20872.8 2000-01-07
# 32140   $96553.6 2000-11-28
# 32141   $70969.6 2000-02-02
# 32142   $83706.0 2000-04-04
# 32143   $89440.0 2000-03-07
# 32144   $76960.0 2000-03-04
# 32145   $80916.0 2000-05-22
# 32146   $66492.0 2000-05-03
# 32147   $16525.6 2000-03-15
# 32148   $70408.0 2000-11-02
# 32149   $68472.0 2000-10-15
# 32150   $78012.0 2000-02-15
# 32151   $81906.0 2000-06-01
# 32152   $80724.0 2000-03-04
# 32153   $75372.0 2000-10-04
# 32154   $91353.6 2000-08-21
# 32155   $96553.6 2000-05-24
# 32156   $80724.0 2000-03-09
# 32157   $78012.0 2000-01-07
# 32158   $80724.0 2000-05-02
# 32159  $110352.0 2000-08-10
#
# [32160 rows x 5 columns]

# %%
import pandas as pd
from dateutil import parser

# %%
sd
# Out:
#                            Name  \
# 0               AARON,  ELVIA J
# 1             AARON,  JEFFERY M
# 2                AARON,  KARINA
# 3           AARON,  KIMBERLEI R
# 4           ABAD JR,  VICENTE M
# 5               ABARCA,  ANABEL
# 6             ABARCA,  EMMANUEL
# 7         ABBATACOLA,  ROBERT J
# 8         ABBATEMARCO,  JAMES J
# 9              ABBATE,  TERRY M
# 10             ABBOTT,  BETTY L
# 11            ABBOTT,  LYNISE M
# 12       ABBRUZZESE,  WILLIAM J
# 13              ABDALLAH,  ZAID
# 14        ABDELHADI,  ABDALMAHD
# 15          ABDELLATIF,  AREF R
# 16           ABDELMAJEID,  AZIZ
# 17          ABDOLLAHZADEH,  ALI
# 18     ABDUL-KARIM,  MUHAMMAD A
# 19             ABDULLAH,  ASKIA
# 20          ABDULLAH,  DANIEL N
# 21             ABDULLAH,  KEVIN
# 22         ABDULLAH,  LAKENYA N
# 23          ABDULLAH,  RASHAD J
# 24         ABDUL-SHAKUR,  TAHIR
# 25            ABEJERO,  JASON V
# 26        ABERCROMBIE,  TIMOTHY
# 27       ABOUELKHEIR,  HASSAN A
# 28           ABRAHAM,  GIRLEY T
# 29           ABRAHAM,  GODWIN K
# ...                         ...
# 32130           ZUNIGA,  JUAN M
# 32131           ZUNIGA,  JURDON
# 32132            ZUNIGA,  OSCAR
# 32133           ZUNIGA,  RONALD
# 32134           ZUNIGA,  THOMAS
# 32135          ZUNIGA,  VICENTE
# 32136               ZUNO,  ERIK
# 32137            ZUPAN,  BILL M
# 32138        ZUPAN,  VICTORIA J
# 32139        ZURAWSKI,  CAROL A
# 32140        ZURAWSKI,  JEFFREY
# 32141          ZURAWSKI,  MAC Z
# 32142         ZURAWSKI,  MARY E
# 32143           ZUREK,  FRANCIS
# 32144             ZUREK,  HENRY
# 32145            ZUREK,  MARY H
# 32146           ZVANJA,  TINA M
# 32147    ZWARYCZ MANN,  IRENE A
# 32148        ZWARYCZ,  THOMAS J
# 32149        ZWIESLER,  MATTHEW
# 32150          ZWIT,  JEFFREY J
# 32151       ZWOLFER,  MATTHEW W
# 32152          ZWOLSKI,  MARY L
# 32153             ZYDEK,  BRYAN
# 32154          ZYGADLO,  JOHN P
# 32155       ZYGADLO,  MICHAEL J
# 32156        ZYGOWICZ,  PETER J
# 32157         ZYMANTAS,  MARK E
# 32158       ZYRKOWSKI,  CARLO E
# 32159       ZYSKOWSKI,  DARIUSZ
#
#                                                  Job        Department  \
# 0                                   WATER RATE TAKER       WATER MGMNT
# 1                                     POLICE OFFICER            POLICE
# 2                                     POLICE OFFICER            POLICE
# 3                           CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4                                  CIVIL ENGINEER IV       WATER MGMNT
# 5                               ASST TO THE ALDERMAN      CITY COUNCIL
# 6                              GENERAL LABORER - DSS     STREETS & SAN
# 7                                ELECTRICAL MECHANIC          AVIATION
# 8                                      FIRE ENGINEER              FIRE
# 9                                     POLICE OFFICER            POLICE
# 10                                FOSTER GRANDPARENT  FAMILY & SUPPORT
# 11                                         CLERK III            POLICE
# 12                            INVESTIGATOR - IPRA II              IPRA
# 13                                    POLICE OFFICER            POLICE
# 14                                    POLICE OFFICER            POLICE
# 15     FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC              FIRE
# 16                                    POLICE OFFICER            POLICE
# 17                                     PARAMEDIC I/C              FIRE
# 18                         ENGINEERING TECHNICIAN VI       WATER MGMNT
# 19                                  LEGISLATIVE AIDE      CITY COUNCIL
# 20                                   FIREFIGHTER-EMT              FIRE
# 21                                        LIEUTENANT              FIRE
# 22                                    CROSSING GUARD            POLICE
# 23           ELECTRICAL MECHANIC-AUTO-POLICE MTR MNT  GENERAL SERVICES
# 24                             GENERAL LABORER - DSS     STREETS & SAN
# 25                                    POLICE OFFICER            POLICE
# 26                                MOTOR TRUCK DRIVER     STREETS & SAN
# 27                         SENIOR PROGRAMMER/ANALYST  FAMILY & SUPPORT
# 28                                 CIVIL ENGINEER IV       WATER MGMNT
# 29                          ENGINEERING TECHNICIAN V  BUSINESS AFFAIRS
# ...                                              ...               ...
# 32130                                 POLICE OFFICER            POLICE
# 32131                                 POLICE OFFICER            POLICE
# 32132                                 POLICE OFFICER            POLICE
# 32133                                 POLICE OFFICER            POLICE
# 32134                          GENERAL LABORER - DSS     STREETS & SAN
# 32135                                FIREFIGHTER-EMT              FIRE
# 32136                           LABORER - APPRENTICE       WATER MGMNT
# 32137                                 LIEUTENANT-EMT              FIRE
# 32138                                 POLICE OFFICER            POLICE
# 32139                                 CROSSING GUARD            POLICE
# 32140                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32141                             SANITATION LABORER     STREETS & SAN
# 32142                                 POLICE OFFICER            POLICE
# 32143                            ELECTRICAL MECHANIC              OEMC
# 32144                           CONSTRUCTION LABORER       WATER MGMNT
# 32145              SENIOR PUBLIC INFORMATION OFFICER           FINANCE
# 32146                                LEGAL SECRETARY               LAW
# 32147                                 CROSSING GUARD            POLICE
# 32148                        POOL MOTOR TRUCK DRIVER       WATER MGMNT
# 32149                    AIRPORT OPERATIONS SUPVSR I          AVIATION
# 32150                                 POLICE OFFICER            POLICE
# 32151                                FIREFIGHTER-EMT              FIRE
# 32152                                 POLICE OFFICER            POLICE
# 32153                                 POLICE OFFICER            POLICE
# 32154                         MACHINIST (AUTOMOTIVE)  GENERAL SERVICES
# 32155                 FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32156                                 POLICE OFFICER            POLICE
# 32157                                 POLICE OFFICER            POLICE
# 32158                                 POLICE OFFICER            POLICE
# 32159                        CHIEF DATA BASE ANALYST              DoIT
#
#           Salary       Date
# 0       $87228.0 2000-09-27
# 1       $75372.0 2000-08-04
# 2       $75372.0 2000-01-20
# 3       $80916.0 2000-04-27
# 4       $99648.0 2000-02-11
# 5       $70764.0 2000-11-12
# 6       $40560.0 2000-01-13
# 7       $89440.0 2000-03-25
# 8       $84396.0 2000-06-17
# 9       $80724.0 2000-12-01
# 10       $2756.0 2000-06-27
# 11      $41784.0 2000-01-16
# 12      $65808.0 2000-05-24
# 13      $65016.0 2000-05-13
# 14      $75372.0 2000-04-24
# 15      $90738.0 2000-02-22
# 16      $75372.0 2000-03-15
# 17      $81672.0 2000-03-09
# 18      $96384.0 2000-02-27
# 19      $25008.0 2000-07-24
# 20      $84762.0 2000-01-07
# 21     $102978.0 2000-06-16
# 22      $16525.6 2000-03-03
# 23      $89440.0 2000-01-15
# 24      $40560.0 2000-07-27
# 25      $78012.0 2000-03-15
# 26      $70408.0 2000-05-26
# 27      $99648.0 2000-06-02
# 28      $99648.0 2000-02-12
# 29      $91980.0 2000-12-08
# ...          ...        ...
# 32130   $78012.0 2000-07-01
# 32131   $61530.0 2000-09-11
# 32132   $65016.0 2000-07-21
# 32133   $78012.0 2000-05-02
# 32134   $41849.6 2000-11-28
# 32135   $79140.0 2000-03-27
# 32136   $46176.0 2000-12-11
# 32137   $98394.0 2000-05-13
# 32138   $75372.0 2000-11-24
# 32139   $20872.8 2000-01-07
# 32140   $96553.6 2000-11-28
# 32141   $70969.6 2000-02-02
# 32142   $83706.0 2000-04-04
# 32143   $89440.0 2000-03-07
# 32144   $76960.0 2000-03-04
# 32145   $80916.0 2000-05-22
# 32146   $66492.0 2000-05-03
# 32147   $16525.6 2000-03-15
# 32148   $70408.0 2000-11-02
# 32149   $68472.0 2000-10-15
# 32150   $78012.0 2000-02-15
# 32151   $81906.0 2000-06-01
# 32152   $80724.0 2000-03-04
# 32153   $75372.0 2000-10-04
# 32154   $91353.6 2000-08-21
# 32155   $96553.6 2000-05-24
# 32156   $80724.0 2000-03-09
# 32157   $78012.0 2000-01-07
# 32158   $80724.0 2000-05-02
# 32159  $110352.0 2000-08-10
#
# [32160 rows x 5 columns]

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32160 entries, 0 to 32159
# Data columns (total 5 columns):
# Name          32160 non-null object
# Job           32160 non-null object
# Department    32160 non-null object
# Salary        32160 non-null object
# Date          32160 non-null datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 1.2+ MB

# %%
cols = sd.columns.values

# %%
import pandas as pd
from dateutil import parser

# %%
sd.Salary = sd.Salary.apply(lambda x: int(float(x[1:]))
# Out:
#   File "<ipython-input-124-223a891490e8>", line 1
#     sd.Salary = sd.Salary.apply(lambda x: int(float(x[1:]))
#                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
sd=salary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-c997c145ee27> in <module>()
# ----> 1 sd=salary
#
# NameError: name 'salary' is not defined

# %%
avg_salaries = salary.groupby('Job').mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-aa2ffd989427> in <module>()
# ----> 1 avg_salaries = salary.groupby('Job').mean()
#
# NameError: name 'salary' is not defined

# %% [markdown]
# # SQL is used at a lot of organizations, but is difficult to work with.  This is because it is a [declarative](https://en.wikipedia.org/wiki/Declarative_programming) language, meaning you have to know how to write your code within very tight restrictions.
#
# # By contrast, [Python]( (https://en.wikipedia.org/wiki/Python_(programming_language))) and [R](https://en.wikipedia.org/wiki/R_(programming_language)) are mixes of many programming paradigms, including object-oriented, array, imperative, functional, procedural, and reflective.
#
#
#
# ## People have written interfaces (wrappers) in Python and R for various SQL databases, e.g. [psycopg2](https://wiki.postgresql.org/wiki/Psycopg2_Tutorial) for Python and other things for [R](https://www.r-bloggers.com/getting-started-with-postgresql-in-r/).

# %% [markdown]
# # R's data.table and dplyr libraries have [similar functions to pandas](http://pandas.pydata.org/pandas-docs/stable/comparison_with_r.html)
